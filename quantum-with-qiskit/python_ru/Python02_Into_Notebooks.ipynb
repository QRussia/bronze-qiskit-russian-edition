# %% [markdown]
# <table> <tr>
#         <td  style="background-color:#ffffff;"><a href="https://qsoftware.lu.lv/index.php/qworld/" target="_blank"><img src="..\images\qworld.jpg" width="25%" align="left"></a></td>
#         <td  style="background-color:#ffffff;vertical-align:bottom;">
#             prepared by Abuzer Yakaryilmaz (<a href="http://qworld.lu.lv/index.php/qlatvia/" target="_blank">QLatvia</a>)
#         </td>
# </tr></table>

# %%
# Jupyter ноутбук состоит из одного или более ячеек (блоков).
# Существуют два типа ячеек: Код и Markdown.
# Ячейка кода используется для написания и выполнения вашего кода.
# Ячейка markdown используется для написания текста (описания, отметки, формулы) или включения графических файлов и изображений.
# В ячейке markdown вы можете форматировать ваши записи, используя коды Markdown, HTML или LaTeX.
# По мере работы с материалом вы будете писать код только на python.
# Заинтересованные пользователи также могут использовать ячейки markdown, но для завершения данного материала в этом нет необходимости. 

#
# Тут мы описываем базовое использование ячеек в ноутбуках Jupyter
#

# Это первая ячейка в данном ноутбуке.
# Вы можете писать код на Python здесь, 
# и далее ЗАПУСТИТЬ/ВЫПОЛНИТЬ это
# 1) нажатием на клавиши CTRL+ENTER или SHIFT+ENTER
# 2) кликом на кнопку "Run" в меню


# здесь несколько строк кода на python

print("hello world")
str="*"
for i in range(10):
    print(str)
    str+="*"

# после запуска данной ячейки вывод сразу же появится после данной ячейки
#     вы можете поменять значение в функции "range" (интервал) в коде выше и перезапустить эту ячейку

# %%
# Это вторая ячейка данного ноутбука. 
#
# Используя элемент меню "Insert", вы можете добавить новую ячейку до или после активной ячейки.
#     Когда ячейка выбрана, вы можете удалить ее, используя элемент меню "Edit".
#
# Как вы могли заметить, есть много других опций редактирования под "Edit",
#     например, копировать/вырезать-вставить ячейки и разделить-объединить ячейки.
#

# %% [markdown]
# <b>Это - третья ячейка.</b>
# \
# Это - ячейка типа markdown.
# \
# Тип любой ячейки указан на панели элементов под меню (элемент справа). Вы можете поменять тип ячейки чеоез элемент меню
#
# Вы можете писать код форматов Markdown, HTML и LaTex в этой ячейке.
#
# <i>Двойным нажатием на ячейке вы можете увидеть код данной ячейки.</i> <br>
# <u>Выполняя ячейку, вы можете увидеть конечное содержимое (отформатированное).</u>

# %% [markdown]
# <b>Это - четвертая ячейка.</b>
# \
# Данная ячейка также имеет тип markdown.
#
# LaTex используется для отображения математических выражений, формул и т.д.
#
# Например, $ x^2 + y ^ 2 = \frac{4}{9} $, $ \sum_{i=1}^n (i+2)^{3} $, или $ \left( \begin{array}{rr}  1 & 0 & -1 \\ 2 & -2 & 0 \\ 3 & -1 & -2  \end{array} \right) $.
#
# <i>Двойным нажатием на ячейке вы можете увидеть код.</i> <br>
# <u>Выполнив/запустив ячейку, вы можете увидеть конечное содержимое.</u>

# %% [markdown]
# <h2> Советы </h2>

# %% [markdown]
# Показать номера строк: View $\rightarrow$ Toggle Line Numbers
#
# Командный режим: CTRL+SHIFT+P

# %% [markdown]
# <h2>Магические команды</h2>
#
# Здесь мы перечислим некоторые встроенные магические команды Jupyter ноутбуков, которые мы будем использовать в нашем материале.
#
# Эти команды могу быть выполнены в ячейках с типом code.

# %% [markdown]
# <b><u>Записать содержимое ячейки с типом code</u></b> во внешний файл:
#
#     %%writefile FILENAME.py
# Эта команда должна быть расположена в первой строке ячейки, далее нужно выполнить эту ячейку.
#
# <i> Пример:</i>

# %%
# %%writefile first.py 

print("hello world")

str="*"
for i in range(5):
    print(str)
    str+="*"
# Out:
# Writing first.py

# %% [markdown]
# <b><u>Выполнение внешнего скрипта</u></b> без загрузки его содержимого в ячейку:
#
#     %run FILENAME.py
# <i>Пример:</i>

# %%
# %run first.py

# %% [markdown]
# <b><u>Загрузка внешнего скрипта</u></b> в ячейку:
#
#     %load FILENAME.py
# Как только команда будет выполнена, содержимое ячейки будет заменено на содержимое файла. (Предыдущий содержимое будет удалено.)
#
# Кроме того, эта команда эта команда будет расположена на первой строке и закомментирована.
#
# <i>Пример:</i>

# %%
# %load first.py
